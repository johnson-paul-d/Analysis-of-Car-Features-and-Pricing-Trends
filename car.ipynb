# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  seaborn as sns
import plotly.express as px

# %%
df=pd.read_excel(r"D:\KGIISL DOC\Python\CAR EDA\Car Uncleaned.xlsx")

# %%
df['Transmission Type'].unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.size
# Out:
# 190624

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ### Deduplication

# %%
df.duplicated().sum()
# Out:
# np.int64(715)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# #### Engine fuel type

# %% [markdown]
# a=df['Engine Fuel Type'].mode()
# print (a)

# %%
df[df['Engine Fuel Type'].isnull()]
# Out:
#          Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df[df['Model']=='Verona']
# Out:
#          Make   Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004               NaN      155.0               6.0
# 11322  Suzuki  Verona  2004               NaN      155.0               6.0
# 11323  Suzuki  Verona  2004               NaN      155.0               6.0
# 11324  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11325  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11326  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11327  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11328  Suzuki  Verona  2006  regular unleaded      155.0               6.0
# 11329  Suzuki  Verona  2006  regular unleaded      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# ...

# %%
df[df['Engine Fuel Type'].isnull()]=df[df['Engine Fuel Type'].isnull()].fillna('regular unleaded')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\2451021350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Engine Fuel Type'].isnull()]=df[df['Engine Fuel Type'].isnull()].fillna('regular unleaded')

# %%
df[df['Engine Fuel Type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Engine HP

# %%
df[df['Engine HP'].isnull()]
# Out:
#          Make        Model  Year                Engine Fuel Type  Engine HP  \
# 539      FIAT         500e  2015                        electric        NaN
# 540      FIAT         500e  2016                        electric        NaN
# 541      FIAT         500e  2017                        electric        NaN
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# ...       ...          ...   ...                             ...        ...
# 9850      Kia      Soul EV  2015                        electric        NaN
# 9851      Kia      Soul EV  2015                        electric        NaN
# 9852      Kia      Soul EV  2016                        electric        NaN
# 9853      Kia      Soul EV  2016                        electric        NaN
# 9854      Kia      Soul EV  2016                        electric        NaN
#
# ...

# %% [markdown]
# ##### 500e

# %%
df[df['Model']=='500e']
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 539  FIAT  500e  2015         electric        NaN               0.0
# 540  FIAT  500e  2016         electric        NaN               0.0
# 541  FIAT  500e  2017         electric        NaN               0.0
#
#     Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 539      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
# 540      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
# 541      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
#
#     Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 539      Compact  2dr Hatchback          108       122         819  31800
# 540      Compact  2dr Hatchback          103       121         819  31800
# 541      Compact  2dr Hatchback          103       121         819  31800

# %%
df.loc[(df['Model'] == '500e') & (df['Engine HP'].isnull())]
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 539  FIAT  500e  2015         electric        NaN               0.0
# 540  FIAT  500e  2016         electric        NaN               0.0
# 541  FIAT  500e  2017         electric        NaN               0.0
#
#     Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 539      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
# 540      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
# 541      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
#
#     Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 539      Compact  2dr Hatchback          108       122         819  31800
# 540      Compact  2dr Hatchback          103       121         819  31800
# 541      Compact  2dr Hatchback          103       121         819  31800

# %%
df.loc[(df['Model'] == '500e') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == '500e') & (df['Engine HP'].isnull())].fillna(111)

# %%
df[df['Model']=='500e']
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 539  FIAT  500e  2015         electric      111.0               0.0
# 540  FIAT  500e  2016         electric      111.0               0.0
# 541  FIAT  500e  2017         electric      111.0               0.0
#
#     Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 539      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
# 540      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
# 541      DIRECT_DRIVE  front wheel drive              2.0       Hatchback
#
#     Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 539      Compact  2dr Hatchback          108       122         819  31800
# 540      Compact  2dr Hatchback          103       121         819  31800
# 541      Compact  2dr Hatchback          103       121         819  31800

# %% [markdown]
# #### Continental

# %%
df[df['Model']=='Continental']
# Out:
#          Make        Model  Year                Engine Fuel Type  Engine HP  \
# 2891  Bentley  Continental  2001     premium unleaded (required)      420.0
# 2892  Bentley  Continental  2001     premium unleaded (required)      400.0
# 2893  Bentley  Continental  2001     premium unleaded (required)      420.0
# 2894  Bentley  Continental  2001     premium unleaded (required)      420.0
# 2895  Bentley  Continental  2003     premium unleaded (required)      420.0
# 2896  Bentley  Continental  2003     premium unleaded (required)      420.0
# 2897  Lincoln  Continental  2001                regular unleaded      275.0
# 2898  Lincoln  Continental  2002     premium unleaded (required)      275.0
# 2899  Lincoln  Continental  2002     premium unleaded (required)      275.0
# 2900  Lincoln  Continental  2002     premium unleaded (required)      275.0
# 2901  Lincoln  Continental  2002     premium unleaded (required)      275.0
# ...

# %%
df.loc[(df['Model'] == 'Continental') & (df['Engine HP'].isnull())]
# Out:
#          Make        Model  Year                Engine Fuel Type  Engine HP  \
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2907  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2908  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 2905               6.0         AUTOMATIC    all wheel drive              4.0
# 2906               6.0         AUTOMATIC  front wheel drive              4.0
# 2907               6.0         AUTOMATIC  front wheel drive              4.0
# 2908               6.0         AUTOMATIC    all wheel drive              4.0
#
#      Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 2905          Luxury        Large         Sedan           25        17
# ...

# %%
df.loc[(df['Model'] == 'Continental') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Continental') & (df['Engine HP'].isnull())].fillna(305)

# %%
df.loc[(df['Model'] == 'Continental') & (df['Engine HP'])]
# Out:
#          Make        Model  Year                Engine Fuel Type  Engine HP  \
# 2891  Bentley  Continental  2001     premium unleaded (required)      420.0
# 2892  Bentley  Continental  2001     premium unleaded (required)      400.0
# 2893  Bentley  Continental  2001     premium unleaded (required)      420.0
# 2894  Bentley  Continental  2001     premium unleaded (required)      420.0
# 2895  Bentley  Continental  2003     premium unleaded (required)      420.0
# 2896  Bentley  Continental  2003     premium unleaded (required)      420.0
# 2897  Lincoln  Continental  2001                regular unleaded      275.0
# 2898  Lincoln  Continental  2002     premium unleaded (required)      275.0
# 2899  Lincoln  Continental  2002     premium unleaded (required)      275.0
# 2900  Lincoln  Continental  2002     premium unleaded (required)      275.0
# 2901  Lincoln  Continental  2002     premium unleaded (required)      275.0
# ...

# %% [markdown]
# #### Soul ev

# %%
df[df['Model']=='Soul EV']
# Out:
#      Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 9850  Kia  Soul EV  2015         electric        NaN               0.0
# 9851  Kia  Soul EV  2015         electric        NaN               0.0
# 9852  Kia  Soul EV  2016         electric        NaN               0.0
# 9853  Kia  Soul EV  2016         electric        NaN               0.0
# 9854  Kia  Soul EV  2016         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 9850      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9851      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9852      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9853      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9854      DIRECT_DRIVE  front wheel drive              4.0             NaN
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
df.loc[(df['Model'] == 'Soul EV') & (df['Engine HP'].isnull())]
# Out:
#      Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 9850  Kia  Soul EV  2015         electric        NaN               0.0
# 9851  Kia  Soul EV  2015         electric        NaN               0.0
# 9852  Kia  Soul EV  2016         electric        NaN               0.0
# 9853  Kia  Soul EV  2016         electric        NaN               0.0
# 9854  Kia  Soul EV  2016         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 9850      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9851      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9852      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9853      DIRECT_DRIVE  front wheel drive              4.0             NaN
# 9854      DIRECT_DRIVE  front wheel drive              4.0             NaN
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
df.loc[(df['Model'] == 'Soul EV') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Soul EV') & (df['Engine HP'].isnull())].fillna(109)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\50296363.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[(df['Model'] == 'Soul EV') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Soul EV') & (df['Engine HP'].isnull())].fillna(109)

# %%
df.loc[(df['Model'] == 'Soul EV') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# ##### Checking for null values

# %%
df[df['Engine HP'].isnull()]
# Out:
#                Make     Model  Year                  Engine Fuel Type  \
# 4203           Ford    Escape  2017                  regular unleaded
# 4204           Ford    Escape  2017                  regular unleaded
# 4205           Ford    Escape  2017                  regular unleaded
# 4206           Ford    Escape  2017                  regular unleaded
# 4705          Honda    Fit EV  2013                          electric
# 4706          Honda    Fit EV  2014                          electric
# 4785           Ford     Focus  2015                          electric
# 4789           Ford     Focus  2016                          electric
# 4798           Ford     Focus  2017                          electric
# 4914           Ford  Freestar  2005                  regular unleaded
# 4915           Ford  Freestar  2005                  regular unleaded
# 4916           Ford  Freestar  2005                  regular unleaded
# ...

# %% [markdown]
# #### FORD escape

# %%
df[df['Model']=='Escape']
# Out:
#       Make   Model  Year                Engine Fuel Type  Engine HP  \
# 4192  Ford  Escape  2015  premium unleaded (recommended)      178.0
# 4193  Ford  Escape  2015  premium unleaded (recommended)      178.0
# 4194  Ford  Escape  2015  premium unleaded (recommended)      178.0
# 4195  Ford  Escape  2015                regular unleaded      168.0
# 4196  Ford  Escape  2015  premium unleaded (recommended)      178.0
# 4197  Ford  Escape  2016  premium unleaded (recommended)      178.0
# 4198  Ford  Escape  2016  premium unleaded (recommended)      178.0
# 4199  Ford  Escape  2016  premium unleaded (recommended)      178.0
# 4200  Ford  Escape  2016                regular unleaded      168.0
# 4201  Ford  Escape  2016  premium unleaded (recommended)      178.0
# 4202  Ford  Escape  2017                regular unleaded      168.0
# 4203  Ford  Escape  2017                regular unleaded        NaN
# 4204  Ford  Escape  2017                regular unleaded        NaN
# ...

# %%
df.loc[(df['Model'] == 'Escape') & (df['Engine HP'].isnull())]
# Out:
#       Make   Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 4203  Ford  Escape  2017  regular unleaded        NaN               4.0
# 4204  Ford  Escape  2017  regular unleaded        NaN               4.0
# 4205  Ford  Escape  2017  regular unleaded        NaN               4.0
# 4206  Ford  Escape  2017  regular unleaded        NaN               4.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 4203         AUTOMATIC  front wheel drive              4.0       Crossover
# 4204         AUTOMATIC    all wheel drive              4.0       Crossover
# 4205         AUTOMATIC    all wheel drive              4.0       Crossover
# 4206         AUTOMATIC  front wheel drive              4.0       Crossover
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 4203      Compact       4dr SUV           30        23        5657  29100
# 4204      Compact       4dr SUV           28        22        5657  30850
# ...

# %%
df.loc[(df['Model'] == 'Escape') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Escape') & (df['Engine HP'].isnull())].fillna(168)

# %%
df.loc[(df['Model'] == 'Escape') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### FORD focus

# %%
df[df['Model']=='Focus']
# Out:
#       Make  Model  Year          Engine Fuel Type  Engine HP  \
# 4780  Ford  Focus  2015  flex-fuel (unleaded/E85)      160.0
# 4781  Ford  Focus  2015  flex-fuel (unleaded/E85)      160.0
# 4782  Ford  Focus  2015  flex-fuel (unleaded/E85)      160.0
# 4783  Ford  Focus  2015  flex-fuel (unleaded/E85)      160.0
# 4784  Ford  Focus  2015  flex-fuel (unleaded/E85)      160.0
# 4785  Ford  Focus  2015                  electric        NaN
# 4786  Ford  Focus  2016  flex-fuel (unleaded/E85)      160.0
# 4787  Ford  Focus  2016  flex-fuel (unleaded/E85)      160.0
# 4788  Ford  Focus  2016  flex-fuel (unleaded/E85)      160.0
# 4789  Ford  Focus  2016                  electric        NaN
# 4790  Ford  Focus  2016  flex-fuel (unleaded/E85)      160.0
# 4791  Ford  Focus  2016  flex-fuel (unleaded/E85)      160.0
# 4792  Ford  Focus  2017  flex-fuel (unleaded/E85)      160.0
# 4793  Ford  Focus  2017          regular unleaded      123.0
# ...

# %%
df.loc[(df['Model'] == 'Focus') & (df['Engine HP'].isnull())]
# Out:
#       Make  Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 4785  Ford  Focus  2015         electric        NaN               0.0
# 4789  Ford  Focus  2016         electric        NaN               0.0
# 4798  Ford  Focus  2017         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 4785      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
# 4789      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
# 4798      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 4785      Compact  4dr Hatchback           99       110        5657  29170
# 4789      Compact  4dr Hatchback           99       110        5657  29170
# 4798      Compact  4dr Hatchback           99       110        5657  29120

# %%
df.loc[(df['Model'] == 'Focus') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Focus') & (df['Engine HP'].isnull())].fillna(143)

# %%
df.loc[(df['Model'] == 'Focus') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### FORD 	Freestar

# %%
df[df['Model']=='Freestar']
# Out:
#       Make     Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 4914  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4915  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4916  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4917  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4918  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4919  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4920  Ford  Freestar  2006  regular unleaded      193.0               6.0
# 4921  Ford  Freestar  2006  regular unleaded      201.0               6.0
# 4922  Ford  Freestar  2006  regular unleaded      193.0               6.0
# 4923  Ford  Freestar  2006  regular unleaded      201.0               6.0
# 4924  Ford  Freestar  2007  regular unleaded      201.0               6.0
# 4925  Ford  Freestar  2007  regular unleaded      201.0               6.0
# ...

# %%
df.loc[(df['Model'] == 'Freestar') & (df['Engine HP'].isnull())]
# Out:
#       Make     Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 4914  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4915  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4916  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4917  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4918  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4919  Ford  Freestar  2005  regular unleaded        NaN               6.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 4914         AUTOMATIC  front wheel drive              4.0             NaN
# 4915         AUTOMATIC  front wheel drive              4.0             NaN
# 4916         AUTOMATIC  front wheel drive              4.0             NaN
# 4917         AUTOMATIC  front wheel drive              4.0             NaN
# ...

# %%
df.loc[(df['Model'] == 'Freestar') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Freestar') & (df['Engine HP'].isnull())].fillna(193)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\3597102707.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[(df['Model'] == 'Freestar') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Freestar') & (df['Engine HP'].isnull())].fillna(193)

# %%
df.loc[(df['Model'] == 'Freestar') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Chev Impala

# %%
df[df['Model']=='Impala']
# Out:
#            Make   Model  Year                  Engine Fuel Type  Engine HP  \
# 5823  Chevrolet  Impala  2015                  regular unleaded      195.0
# 5824  Chevrolet  Impala  2015                  regular unleaded      195.0
# 5825  Chevrolet  Impala  2015  flex-fuel (unleaded/natural gas)        NaN
# 5826  Chevrolet  Impala  2015          flex-fuel (unleaded/E85)      305.0
# 5827  Chevrolet  Impala  2015          flex-fuel (unleaded/E85)      305.0
# 5828  Chevrolet  Impala  2015                  regular unleaded      195.0
# 5830  Chevrolet  Impala  2015  flex-fuel (unleaded/natural gas)        NaN
# 5831  Chevrolet  Impala  2016  flex-fuel (unleaded/natural gas)        NaN
# 5832  Chevrolet  Impala  2016          flex-fuel (unleaded/E85)      305.0
# 5833  Chevrolet  Impala  2016  flex-fuel (unleaded/natural gas)        NaN
# 5834  Chevrolet  Impala  2016          flex-fuel (unleaded/E85)      305.0
# ...

# %%
df.loc[(df['Model'] == 'Impala') & (df['Engine HP'].isnull())]
# Out:
#            Make   Model  Year                  Engine Fuel Type  Engine HP  \
# 5825  Chevrolet  Impala  2015  flex-fuel (unleaded/natural gas)        NaN
# 5830  Chevrolet  Impala  2015  flex-fuel (unleaded/natural gas)        NaN
# 5831  Chevrolet  Impala  2016  flex-fuel (unleaded/natural gas)        NaN
# 5833  Chevrolet  Impala  2016  flex-fuel (unleaded/natural gas)        NaN
# 5839  Chevrolet  Impala  2017  flex-fuel (unleaded/natural gas)        NaN
# 5840  Chevrolet  Impala  2017  flex-fuel (unleaded/natural gas)        NaN
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 5825               6.0         AUTOMATIC  front wheel drive              4.0
# 5830               6.0         AUTOMATIC  front wheel drive              4.0
# 5831               6.0         AUTOMATIC  front wheel drive              4.0
# 5833               6.0         AUTOMATIC  front wheel drive              4.0
# ...

# %%
df.loc[(df['Model'] == 'Impala') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Impala') & (df['Engine HP'].isnull())].fillna(305)

# %%
df.loc[(df['Model'] == 'Impala') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Nissan Leaf

# %%
df[df['Model']=='Leaf']
# Out:
#         Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6385  Nissan  Leaf  2014         electric        NaN               0.0
# 6386  Nissan  Leaf  2014         electric        NaN               0.0
# 6387  Nissan  Leaf  2014         electric        NaN               0.0
# 6388  Nissan  Leaf  2015         electric        NaN               0.0
# 6389  Nissan  Leaf  2015         electric        NaN               0.0
# 6390  Nissan  Leaf  2015         electric        NaN               0.0
# 6391  Nissan  Leaf  2015         electric        NaN               0.0
# 6392  Nissan  Leaf  2016         electric        NaN               0.0
# 6393  Nissan  Leaf  2016         electric        NaN               0.0
# 6394  Nissan  Leaf  2016         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 6385      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
# ...

# %%
df.loc[(df['Model'] == 'Leaf') & (df['Engine HP'].isnull())]
# Out:
#         Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6385  Nissan  Leaf  2014         electric        NaN               0.0
# 6386  Nissan  Leaf  2014         electric        NaN               0.0
# 6387  Nissan  Leaf  2014         electric        NaN               0.0
# 6388  Nissan  Leaf  2015         electric        NaN               0.0
# 6389  Nissan  Leaf  2015         electric        NaN               0.0
# 6390  Nissan  Leaf  2015         electric        NaN               0.0
# 6391  Nissan  Leaf  2015         electric        NaN               0.0
# 6392  Nissan  Leaf  2016         electric        NaN               0.0
# 6393  Nissan  Leaf  2016         electric        NaN               0.0
# 6394  Nissan  Leaf  2016         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 6385      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
# ...

# %%
df.loc[(df['Model'] == 'Leaf') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Leaf') & (df['Engine HP'].isnull())].fillna(107)

# %%
df.loc[(df['Model'] == 'Leaf') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# ### Rechecking Null values

# %%
df[df['Engine HP'].isnull()]
# Out:
#                Make    Model  Year  Engine Fuel Type  Engine HP  \
# 4705          Honda   Fit EV  2013          electric        NaN
# 4706          Honda   Fit EV  2014          electric        NaN
# 5778     Mitsubishi   i-MiEV  2014          electric        NaN
# 6578  Mercedes-Benz  M-Class  2015            diesel        NaN
# 6908        Lincoln      MKZ  2017  regular unleaded        NaN
# 6910        Lincoln      MKZ  2017  regular unleaded        NaN
# 6916        Lincoln      MKZ  2017  regular unleaded        NaN
# 6918        Lincoln      MKZ  2017  regular unleaded        NaN
# 6921          Tesla  Model S  2014          electric        NaN
# 6922          Tesla  Model S  2014          electric        NaN
# 6923          Tesla  Model S  2014          electric        NaN
# 6924          Tesla  Model S  2014          electric        NaN
# 6925          Tesla  Model S  2015          electric        NaN
# 6926          Tesla  Model S  2015          electric        NaN
# ...

# %% [markdown]
# #### Tesla Model S

# %%
df[df['Model']=='Model S']
# Out:
#        Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6921  Tesla  Model S  2014         electric        NaN               0.0
# 6922  Tesla  Model S  2014         electric        NaN               0.0
# 6923  Tesla  Model S  2014         electric        NaN               0.0
# 6924  Tesla  Model S  2014         electric        NaN               0.0
# 6925  Tesla  Model S  2015         electric        NaN               0.0
# 6926  Tesla  Model S  2015         electric        NaN               0.0
# 6927  Tesla  Model S  2015         electric        NaN               0.0
# 6928  Tesla  Model S  2015         electric        NaN               0.0
# 6929  Tesla  Model S  2015         electric        NaN               0.0
# 6930  Tesla  Model S  2016         electric        NaN               0.0
# 6931  Tesla  Model S  2016         electric        NaN               0.0
# 6932  Tesla  Model S  2016         electric        NaN               0.0
# ...

# %%
df.loc[(df['Model'] == 'Model S') & (df['Engine HP'].isnull())]
# Out:
#        Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6921  Tesla  Model S  2014         electric        NaN               0.0
# 6922  Tesla  Model S  2014         electric        NaN               0.0
# 6923  Tesla  Model S  2014         electric        NaN               0.0
# 6924  Tesla  Model S  2014         electric        NaN               0.0
# 6925  Tesla  Model S  2015         electric        NaN               0.0
# 6926  Tesla  Model S  2015         electric        NaN               0.0
# 6927  Tesla  Model S  2015         electric        NaN               0.0
# 6928  Tesla  Model S  2015         electric        NaN               0.0
# 6929  Tesla  Model S  2015         electric        NaN               0.0
# 6930  Tesla  Model S  2016         electric        NaN               0.0
# 6931  Tesla  Model S  2016         electric        NaN               0.0
# 6932  Tesla  Model S  2016         electric        NaN               0.0
# ...

# %% [markdown]
# #### All wheel drive

# %%
df.loc[(df['Model'] == 'Model S') & (df['Driven_Wheels']=='all wheel drive') & (df['Engine HP'].isnull())]
# Out:
#        Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6923  Tesla  Model S  2014         electric        NaN               0.0
# 6926  Tesla  Model S  2015         electric        NaN               0.0
# 6927  Tesla  Model S  2015         electric        NaN               0.0
# 6928  Tesla  Model S  2015         electric        NaN               0.0
# 6930  Tesla  Model S  2016         electric        NaN               0.0
# 6931  Tesla  Model S  2016         electric        NaN               0.0
# 6932  Tesla  Model S  2016         electric        NaN               0.0
# 6934  Tesla  Model S  2016         electric        NaN               0.0
# 6935  Tesla  Model S  2016         electric        NaN               0.0
# 6936  Tesla  Model S  2016         electric        NaN               0.0
# 6937  Tesla  Model S  2016         electric        NaN               0.0
#
#      Transmission Type    Driven_Wheels  Number of Doors  \
# ...

# %%
df.loc[(df['Model'] == 'Model S') & (df['Driven_Wheels'] == 'all wheel drive') & (df['Engine HP'].isnull()), 'Engine HP'] = 691

# %%
df.loc[(df['Model'] == 'Model S') & (df['Driven_Wheels']=='all wheel drive') & (df['Engine HP'])]
# Out:
#        Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6923  Tesla  Model S  2014         electric      691.0               0.0
# 6926  Tesla  Model S  2015         electric      691.0               0.0
# 6927  Tesla  Model S  2015         electric      691.0               0.0
# 6928  Tesla  Model S  2015         electric      691.0               0.0
# 6930  Tesla  Model S  2016         electric      691.0               0.0
# 6931  Tesla  Model S  2016         electric      691.0               0.0
# 6932  Tesla  Model S  2016         electric      691.0               0.0
# 6934  Tesla  Model S  2016         electric      691.0               0.0
# 6935  Tesla  Model S  2016         electric      691.0               0.0
# 6936  Tesla  Model S  2016         electric      691.0               0.0
# 6937  Tesla  Model S  2016         electric      691.0               0.0
#
#      Transmission Type    Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# #### rear wheel drive

# %%
df.loc[(df['Model'] == 'Model S') & (df['Driven_Wheels']=='rear wheel drive') & (df['Engine HP'].isnull())]
# Out:
#        Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6921  Tesla  Model S  2014         electric        NaN               0.0
# 6922  Tesla  Model S  2014         electric        NaN               0.0
# 6924  Tesla  Model S  2014         electric        NaN               0.0
# 6925  Tesla  Model S  2015         electric        NaN               0.0
# 6929  Tesla  Model S  2015         electric        NaN               0.0
# 6933  Tesla  Model S  2016         electric        NaN               0.0
# 6938  Tesla  Model S  2016         electric        NaN               0.0
#
#      Transmission Type     Driven_Wheels  Number of Doors  \
# 6921      DIRECT_DRIVE  rear wheel drive              4.0
# 6922      DIRECT_DRIVE  rear wheel drive              4.0
# 6924      DIRECT_DRIVE  rear wheel drive              4.0
# 6925      DIRECT_DRIVE  rear wheel drive              4.0
# 6929      DIRECT_DRIVE  rear wheel drive              4.0
# ...

# %%
df.loc[(df['Model'] == 'Model S') & (df['Driven_Wheels'] == 'rear wheel drive') & (df['Engine HP'].isnull()), 'Engine HP'] = 691

# %%
df.loc[(df['Model'] == 'Model S') & (df['Driven_Wheels']=='rear wheel drive') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Honda Fit EV

# %%
df[df['Model']=='Fit EV']
# Out:
#        Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 4705  Honda  Fit EV  2013         electric        NaN               0.0
# 4706  Honda  Fit EV  2014         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 4705      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
# 4706      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 4705      Compact  4dr Hatchback          105       132        2202  36625
# 4706      Compact  4dr Hatchback          105       132        2202  36625

# %%
df.loc[(df['Model'] == 'Fit EV') & (df['Engine HP'].isnull())]
# Out:
#        Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 4705  Honda  Fit EV  2013         electric        NaN               0.0
# 4706  Honda  Fit EV  2014         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 4705      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
# 4706      DIRECT_DRIVE  front wheel drive              4.0       Hatchback
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 4705      Compact  4dr Hatchback          105       132        2202  36625
# 4706      Compact  4dr Hatchback          105       132        2202  36625

# %%
df.loc[(df['Model'] == 'Fit EV') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'Fit EV') & (df['Engine HP'].isnull())].fillna(123)

# %%
df.loc[(df['Model'] == 'Fit EV') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Lincoln MKZ

# %%
df[df['Model']=='MKZ']
# Out:
#          Make Model  Year                Engine Fuel Type  Engine HP  \
# 6896  Lincoln   MKZ  2015                regular unleaded      231.0
# 6897  Lincoln   MKZ  2015                regular unleaded      231.0
# 6898  Lincoln   MKZ  2015                regular unleaded      188.0
# 6899  Lincoln   MKZ  2015                regular unleaded      231.0
# 6900  Lincoln   MKZ  2015                regular unleaded      188.0
# 6901  Lincoln   MKZ  2015                regular unleaded      231.0
# 6902  Lincoln   MKZ  2016                regular unleaded      231.0
# 6903  Lincoln   MKZ  2016                regular unleaded      188.0
# 6904  Lincoln   MKZ  2016                regular unleaded      231.0
# 6905  Lincoln   MKZ  2016                regular unleaded      231.0
# 6906  Lincoln   MKZ  2016                regular unleaded      188.0
# 6907  Lincoln   MKZ  2016                regular unleaded      231.0
# 6908  Lincoln   MKZ  2017                regular unleaded        NaN
# ...

# %%
df.loc[(df['Model'] == 'MKZ') & (df['Engine HP'].isnull())]
# Out:
#          Make Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6908  Lincoln   MKZ  2017  regular unleaded        NaN               4.0
# 6910  Lincoln   MKZ  2017  regular unleaded        NaN               4.0
# 6916  Lincoln   MKZ  2017  regular unleaded        NaN               4.0
# 6918  Lincoln   MKZ  2017  regular unleaded        NaN               4.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 6908         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
# 6910         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
# 6916         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
# 6918         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 6908      Midsize         Sedan           38        41          61  35010
# 6910      Midsize         Sedan           38        41          61  39510
# ...

# %%
df.loc[(df['Model'] == 'MKZ') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'MKZ') & (df['Engine HP'].isnull())].fillna(245)

# %%
df.loc[(df['Model'] == 'MKZ') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Toyota RAV4EV

# %%
df[df['Model']=='RAV4 EV']
# Out:
#         Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 8373  Toyota  RAV4 EV  2012         electric      154.0               NaN
# 8374  Toyota  RAV4 EV  2013         electric        NaN               0.0
# 8375  Toyota  RAV4 EV  2014         electric        NaN               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 8373      DIRECT_DRIVE  front wheel drive              4.0       Crossover
# 8374      DIRECT_DRIVE  front wheel drive              4.0       Crossover
# 8375      DIRECT_DRIVE  front wheel drive              4.0       Crossover
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 8373      Midsize       4dr SUV           74        78        2031  49800
# 8374      Midsize       4dr SUV           74        78        2031  49800
# 8375      Midsize       4dr SUV           74        78        2031  49800

# %%
df.loc[df['Model'] == 'RAV4 EV', 'Engine HP'] = 155

# %%
df[df['Model']=='RAV4 EV']
# Out:
#         Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 8373  Toyota  RAV4 EV  2012         electric      155.0               NaN
# 8374  Toyota  RAV4 EV  2013         electric      155.0               0.0
# 8375  Toyota  RAV4 EV  2014         electric      155.0               0.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 8373      DIRECT_DRIVE  front wheel drive              4.0       Crossover
# 8374      DIRECT_DRIVE  front wheel drive              4.0       Crossover
# 8375      DIRECT_DRIVE  front wheel drive              4.0       Crossover
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 8373      Midsize       4dr SUV           74        78        2031  49800
# 8374      Midsize       4dr SUV           74        78        2031  49800
# 8375      Midsize       4dr SUV           74        78        2031  49800

# %% [markdown]
# #### Benz M-Class

# %%
df[df['Model']=='M-Class']
# Out:
#                Make    Model  Year             Engine Fuel Type  Engine HP  \
# 6566  Mercedes-Benz  M-Class  2013                       diesel      240.0
# 6567  Mercedes-Benz  M-Class  2013  premium unleaded (required)      518.0
# 6568  Mercedes-Benz  M-Class  2013  premium unleaded (required)      402.0
# 6569  Mercedes-Benz  M-Class  2013  premium unleaded (required)      302.0
# 6570  Mercedes-Benz  M-Class  2013  premium unleaded (required)      302.0
# 6571  Mercedes-Benz  M-Class  2014  premium unleaded (required)      518.0
# 6572  Mercedes-Benz  M-Class  2014                       diesel      240.0
# 6573  Mercedes-Benz  M-Class  2014  premium unleaded (required)      302.0
# 6574  Mercedes-Benz  M-Class  2014  premium unleaded (required)      402.0
# 6575  Mercedes-Benz  M-Class  2014  premium unleaded (required)      302.0
# 6576  Mercedes-Benz  M-Class  2015  premium unleaded (required)      329.0
# ...

# %%
df.loc[(df['Model'] == 'M-Class') & (df['Engine HP'].isnull())]
# Out:
#                Make    Model  Year Engine Fuel Type  Engine HP  \
# 6578  Mercedes-Benz  M-Class  2015           diesel        NaN
#
#       Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 6578               4.0         AUTOMATIC  all wheel drive              4.0
#
#               Market Category Vehicle Size Vehicle Style  highway MPG  \
# 6578  Crossover,Luxury,Diesel      Midsize       4dr SUV           29
#
#       city mpg  Popularity   MSRP
# 6578        22         617  49800

# %%
df.loc[(df['Model'] == 'M-Class') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'M-Class') & (df['Engine HP'].isnull())].fillna(258)

# %%
df.loc[(df['Model'] == 'M-Class') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
df[df['Model']=='i-MiEV']
# Out:
#             Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5778  Mitsubishi  i-MiEV  2014         electric        NaN               NaN
# 5779  Mitsubishi  i-MiEV  2016         electric       66.0               NaN
# 5780  Mitsubishi  i-MiEV  2017         electric       66.0               NaN
#
#      Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 5778      DIRECT_DRIVE  rear wheel drive              4.0       Hatchback
# 5779      DIRECT_DRIVE  rear wheel drive              4.0       Hatchback
# 5780      DIRECT_DRIVE  rear wheel drive              4.0       Hatchback
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 5778      Compact  4dr Hatchback           99       126         436  22995
# 5779      Compact  4dr Hatchback           99       126         436  22995
# 5780      Compact  4dr Hatchback          102       121         436  22995

# %%
df.loc[(df['Model'] == 'i-MiEV') & (df['Engine HP'].isnull())]
# Out:
#             Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5778  Mitsubishi  i-MiEV  2014         electric        NaN               NaN
#
#      Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 5778      DIRECT_DRIVE  rear wheel drive              4.0       Hatchback
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 5778      Compact  4dr Hatchback           99       126         436  22995

# %%
df.loc[(df['Model'] == 'i-MiEV') & (df['Engine HP'].isnull())]=df.loc[(df['Model'] == 'i-MiEV') & (df['Engine HP'].isnull())].fillna(66)

# %%
df.loc[(df['Model'] == 'i-MiEV') & (df['Engine HP'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# ### NUMBER OF DOORS

# %%
df[df['Number of Doors'].isnull()]
# Out:
#          Make    Model  Year             Engine Fuel Type  Engine HP  \
# 4666  Ferrari       FF  2013  premium unleaded (required)      651.0
# 6930    Tesla  Model S  2016                     electric      691.0
# 6931    Tesla  Model S  2016                     electric      691.0
# 6932    Tesla  Model S  2016                     electric      691.0
# 6933    Tesla  Model S  2016                     electric      691.0
# 6934    Tesla  Model S  2016                     electric      691.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 4666              12.0  AUTOMATED_MANUAL   all wheel drive              NaN
# 6930               0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6931               0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6932               0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6933               0.0      DIRECT_DRIVE  rear wheel drive              NaN
# ...

# %% [markdown]
# #### Tesla

# %%
df.loc[(df['Model'] == 'Model S') & (df['Number of Doors'].isnull())]
# Out:
#        Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6930  Tesla  Model S  2016         electric      691.0               0.0
# 6931  Tesla  Model S  2016         electric      691.0               0.0
# 6932  Tesla  Model S  2016         electric      691.0               0.0
# 6933  Tesla  Model S  2016         electric      691.0               0.0
# 6934  Tesla  Model S  2016         electric      691.0               0.0
#
#      Transmission Type     Driven_Wheels  Number of Doors  \
# 6930      DIRECT_DRIVE   all wheel drive              NaN
# 6931      DIRECT_DRIVE   all wheel drive              NaN
# 6932      DIRECT_DRIVE   all wheel drive              NaN
# 6933      DIRECT_DRIVE  rear wheel drive              NaN
# 6934      DIRECT_DRIVE   all wheel drive              NaN
#
#               Market Category Vehicle Size Vehicle Style  highway MPG  \
# 6930       Exotic,Performance        Large         Sedan          105
# ...

# %%
df.loc[(df['Model'] == 'Model S') & (df['Number of Doors'].isnull())]= df.loc[(df['Model'] == 'Model S') & (df['Number of Doors'].isnull())].fillna(4)

# %%
df.loc[(df['Model'] == 'Model S') & (df['Number of Doors'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# #### Ferrari

# %%
df.loc[(df['Model'] == 'FF') & (df['Number of Doors'].isnull())]
# Out:
#          Make Model  Year             Engine Fuel Type  Engine HP  \
# 4666  Ferrari    FF  2013  premium unleaded (required)      651.0
#
#       Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 4666              12.0  AUTOMATED_MANUAL  all wheel drive              NaN
#
#               Market Category Vehicle Size Vehicle Style  highway MPG  \
# 4666  Exotic,High-Performance        Large         Coupe           16
#
#       city mpg  Popularity    MSRP
# 4666        11        2774  295000

# %%
df.loc[(df['Model'] == 'FF') & (df['Number of Doors'].isnull())]=df.loc[(df['Model'] == 'FF') & (df['Number of Doors'].isnull())].fillna(3)

# %%
df.loc[(df['Model'] == 'FF') & (df['Number of Doors'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders       29
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3362
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ### ENGINE CYLINDERS

# %%
df[df['Engine Cylinders'].isnull()]
# Out:
#             Make    Model  Year             Engine Fuel Type  Engine HP  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      155.0
# 8695       Mazda     RX-7  1993             regular unleaded      255.0
# 8696       Mazda     RX-7  1994             regular unleaded      255.0
# 8697       Mazda     RX-7  1995             regular unleaded      255.0
# ...

# %%
df_null_cylinders = df.loc[df['Engine Cylinders'].isnull()]
print(df_null_cylinders)
# Out:
#             Make    Model  Year             Engine Fuel Type  Engine HP  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      155.0
# 8695       Mazda     RX-7  1993             regular unleaded      255.0
# 8696       Mazda     RX-7  1994             regular unleaded      255.0
# 8697       Mazda     RX-7  1995             regular unleaded      255.0
# ...

# %%
df['Engine Cylinders'].fillna(0, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\3346670025.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine Cylinders'].fillna(0, inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\3346670025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Engine Cylinders'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3362
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Transmission Type'].unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %% [markdown]
# ## MARKET CATEGORY

# %%
df[df['Market Category'].isnull()]
# Out:
#            Make     Model  Year                Engine Fuel Type  Engine HP  \
# 87       Nissan     200SX  1996                regular unleaded      115.0
# 91       Nissan     200SX  1997                regular unleaded      115.0
# 93       Nissan     200SX  1998                regular unleaded      115.0
# 203    Chrysler       300  2015                regular unleaded      300.0
# 204    Chrysler       300  2015                regular unleaded      292.0
# ...         ...       ...   ...                             ...        ...
# 11794    Subaru        XT  1991                regular unleaded      145.0
# 11809    Toyota  Yaris iA  2017                regular unleaded      106.0
# 11810    Toyota  Yaris iA  2017                regular unleaded      106.0
# 11867       GMC     Yukon  2015  premium unleaded (recommended)      420.0
# 11868       GMC     Yukon  2015  premium unleaded (recommended)      420.0
#
# ...

# %%
df['Market Category'].unique()
# Out:
# array(['Factory Tuner,Luxury,High-Performance', 'Luxury,Performance',
#        'Luxury,High-Performance', 'Luxury', 'Performance', 'Flex Fuel',
#        'Flex Fuel,Performance', nan, 'Hatchback',
#        'Hatchback,Luxury,Performance', 'Hatchback,Luxury',
#        'Luxury,High-Performance,Hybrid', 'Diesel,Luxury',
#        'Hatchback,Performance', 'Hatchback,Factory Tuner,Performance',
#        'High-Performance', 'Factory Tuner,High-Performance',
#        'Exotic,High-Performance', 'Exotic,Factory Tuner,High-Performance',
#        'Factory Tuner,Performance', 'Crossover', 'Exotic,Luxury',
#        'Exotic,Luxury,High-Performance', 'Exotic,Luxury,Performance',
#        'Factory Tuner,Luxury,Performance', 'Flex Fuel,Luxury',
#        'Crossover,Luxury', 'Hatchback,Factory Tuner,Luxury,Performance',
#        'Crossover,Hatchback', 'Hybrid', 'Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance',
# ...

# %% [markdown]
# ### Market Category
# **Low Predictive Power:** The near-uniqueness suggests it might have low predictive value because it’s not grouping records into meaningful, reusable categories.
#
# **High Missingness:** One-third missing values is substantial. Imputing may not be useful if each entry is nearly unique and if you lack a reliable way to fill in the gaps.
#
# So it is dropped

# %%
df.drop('Market Category', axis=1, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\2316938878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Market Category', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.to_csv('D:\KGIISL DOC\Python\CAR EDA/cleaned_file.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11260\4254594617.py:1: SyntaxWarning: invalid escape sequence '\K'
#   df.to_csv('D:\KGIISL DOC\Python\CAR EDA/cleaned_file.csv', index=False)

# %% [markdown]
# ## DATA VISUALISATIONS

# %% [markdown]
# #### Multivariate

# %%
fig = px.histogram(df, x='MSRP', color='Vehicle Style', nbins=100, 
                title="MSRP Distribution by Vehicle Style")
fig.update_layout(bargap=0.1, xaxis_title="MSRP", yaxis_title="Count", 
                xaxis=dict(range=[0, 100000]))  # Set x-axis limit to focus on lower values
fig.show()

# %%
sns.pairplot(df)

# %% [markdown]
# #### Insights
# 1. Engine size correlates positively with MSRP and negatively with MPG.
# 2. Higher MSRP vehicles are generally more popular but less fuel-efficient.
# 3. Most vehicles have 4-6 engine cylinders, with higher MSRP outliers.
# 4. Highway MPG tends to be higher than city MPG consistently.
# 5. Recent years show increased popularity and varied engine sizes.

# %%
H = df[['Engine Cylinders', 'Engine HP', 'city mpg', 'Popularity']]
corr = H.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Insights
# Here are five insights from the correlation heatmap:
#
# 1. Engine Cylinders and Engine HP have a strong positive correlation (0.72).
# 2. City MPG has a negative correlation with Engine Cylinders (-0.51).
# 3. City MPG is inversely related to Engine HP with -0.32 correlation.
# 4. Popularity has weak correlations with other variables, close to zero.
# 5. More engine cylinders tend to reduce fuel efficiency (negative MPG correlation).

# %% [markdown]
# ### Univariate Analysis

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
P=px.pie(df,names='Vehicle Size')
P.show()

# %%
sns.histplot(df['Number of Doors'])
# Out:
# <Axes: xlabel='Number of Doors', ylabel='Count'>

# %% [markdown]
# #### Insights
# **Bar Plot of Count by Number of Doors**:
#
# - Vehicles with 4 doors are the most common, likely due to the demand for practicality in family or utility vehicles.
# - 2-door vehicles are also popular, though less so than 4-door models.
# - Vehicles with 3 doors are rare, indicating limited consumer demand or specific use cases.

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='Transmission Type', data=df)
# Out:
# <Axes: xlabel='Transmission Type', ylabel='count'>

# %% [markdown]
# ### Insights
# **Bar Plot of Count by Transmission Type**:
#
# - Automatic transmission is the most common type, indicating a preference for ease of use among drivers.
# - Manual transmission has a significant presence, though it is less popular than automatic.
# - Other transmission types, like automated manual and direct drive, are rare, which may indicate niche applications or specialized vehicles.

# %%
P3=px.box(df, y='Engine HP')
P3.show()

# %% [markdown]
# ## Bivariate

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
sns.lineplot(df, x='Engine HP', y='MSRP')
# Out:
# <Axes: xlabel='Engine HP', ylabel='MSRP'>

# %% [markdown]
# #### Insights
# **Line Plot of MSRP by Engine HP**:
#
# - There is a strong positive relationship between MSRP and engine horsepower; as horsepower increases, so does MSRP.
# - High horsepower vehicles (over 600 HP) have a much wider range in MSRP, with some extreme outliers reaching very high prices.
# - The trend suggests that luxury or performance-focused vehicles with high horsepower command a premium in price.

# %%
sns.lineplot(df, x='Number of Doors', y='MSRP')
# Out:
# <Axes: xlabel='Number of Doors', ylabel='MSRP'>

# %% [markdown]
# #### insights
#
# **Line Plot of MSRP by Number of Doors**:
#
# - Vehicles with 2 doors generally have the highest MSRP, potentially due to sports and luxury models.
# - The lowest MSRP is seen in vehicles with 3 doors, suggesting these may be less expensive, possibly smaller or economy models.
# - Vehicles with 4 doors have higher MSRPs than 3-door vehicles, potentially reflecting the market demand for family cars.

# %%
g = sns.FacetGrid(df, col='Vehicle Size'); g.map(plt.hist, 'MSRP')

# %% [markdown]
# #### Insights
#  **Histogram of MSRP by Vehicle Size**:
#
# - Most compact and midsize vehicles are concentrated in the lower MSRP range.
# - Large vehicles tend to have slightly higher MSRPs, though they still cluster in the lower end of the MSRP scale.
# - All three vehicle sizes have a right-skewed distribution, with few high-priced outliers.

# %%
sns.scatterplot(data=df,x='MSRP',y='city mpg')
# Out:
# <Axes: xlabel='MSRP', ylabel='city mpg'>

# %% [markdown]
# #### Insights
# **Scatter Plot of City MPG vs. MSRP**:
#
# - Lower MSRP vehicles generally have a higher city MPG.
# - There is an inverse relationship between MSRP and city MPG, with high-priced vehicles tending to have lower fuel efficiency.
# - Outliers are visible where some high-MSRP vehicles achieve relatively high MPG, but these are uncommon.

# %%
sns.violinplot(df, x='Vehicle Size', y='city mpg')
# Out:
# <Axes: xlabel='Vehicle Size', ylabel='city mpg'>

# %% [markdown]
# #### Insights
# **Violin Plot of City MPG by Vehicle Size**:
#
# - Compact vehicles tend to have the highest city MPG range, with several outliers reaching high MPG values.
# - Midsize vehicles show a more consistent and narrower range around the lower end of city MPG compared to compact vehicles.
# - Large vehicles generally have lower city MPG, with a tight distribution around a lower average.
